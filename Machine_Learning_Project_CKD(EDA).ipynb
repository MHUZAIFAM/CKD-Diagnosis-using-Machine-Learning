# %%
#Exploratory Data Analysis (EDA)
#Objective:  Understand the characteristics of the data and ensure that everything is in order before moving to model training.
#Tasks:
#Visualize the distribution of features using histograms, box plots, and scatter plots.
#Check the relationships between features and the target variable using correlation matrices or pair plots.
#Identify any potential outliers or anomalies that might need to be addressed.
#Perform class distribution analysis (i.e., whether the target variable is imbalanced).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading and loading the dataset
df = pd.read_csv('kidney_disease_preprocessed.csv')
print("Dataset Loaded Success")
# Out:
# Dataset Loaded Success

# %%
#Printing the first five rows of the dataset
df.head()
# Out:
#         age        bp    sg   al   su  rbc  pc  pcc  ba       bgr  ...  pcv  \
# 0  0.522727  0.230769  0.75  0.2  0.0    1   1    0   0  0.211538  ...   32
# 1  0.056818  0.000000  0.75  0.8  0.0    1   1    0   0  0.269309  ...   26
# 2  0.681818  0.230769  0.25  0.4  0.6    1   1    0   0  0.856838  ...   19
# 3  0.522727  0.153846  0.00  0.8  0.0    1   0    1   0  0.202991  ...   20
# 4  0.556818  0.230769  0.25  0.4  0.0    1   1    0   0  0.179487  ...   23
#
#    wc  rc  htn  dm  cad  appet  pe  ane  classification
# 0  72  34    1   4    1      0   0    0               0
# 1  56  34    0   3    1      0   0    0               0
# 2  70  34    0   4    1      1   0    1               0
# 3  62  19    1   3    1      1   1    1               0
# 4  68  27    0   3    1      0   0    0               0
#
# [5 rows x 25 columns]

# %%
#Getting the summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             400 non-null    float64
#  1   bp              400 non-null    float64
#  2   sg              400 non-null    float64
#  3   al              400 non-null    float64
#  4   su              400 non-null    float64
#  5   rbc             400 non-null    int64
#  6   pc              400 non-null    int64
#  7   pcc             400 non-null    int64
#  8   ba              400 non-null    int64
#  9   bgr             400 non-null    float64
#  10  bu              400 non-null    float64
#  11  sc              400 non-null    float64
#  12  sod             400 non-null    float64
#  13  pot             400 non-null    float64
#  14  hemo            400 non-null    float64
#  15  pcv             400 non-null    int64
#  16  wc              400 non-null    int64
# ...

# %%
#Now check for missing values
df.isnull().sum()
# Out:
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %% [markdown]
# **Visualizing the Dataset**

# %% [markdown]
# Histograms

# %%
#Histogram for the Dataset
histograms = df.hist(figsize=(10,10),bins = 20, color = 'red', edgecolor = 'black')
plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()

# %% [markdown]
# Box PLots

# %%
#Drawing Box Plots
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[['age', 'bp', 'sg','al']])
plt.title('Box Plot for Features')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Class Distribution (Bar/Pie Chart)**

# %% [markdown]
# Bar Plot

# %%
# Visualize class distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='classification', data=df, palette='pastel')
plt.title('Class Distribution')
plt.show()
# Out:
# <ipython-input-12-3741f283afed>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='classification', data=df, palette='pastel')

# %% [markdown]
# PIE Chart

# %%
#To make a pie chart
target_counts = df['classification'].value_counts()
plt.figure(figsize=(8, 8))
plt.title('Class Distribution')
plt.pie(target_counts, labels=target_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.show()

# %% [markdown]
# **Correlation Matrix (Heatmap)**

# %%
# Correlation Matrix (Heatmap)
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **Scatter Plot**

# %%
#To create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='bp', hue='classification', data=df)
plt.title('Scatter Plot of Age vs. Blood Pressure')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs. Blood Pressure')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='sg', hue='classification', data=df)
plt.title('Scatter Plot of Age vs. SG')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs. SG')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='al', hue='classification', data=df)
plt.title('Scatter Plot of Age vs. AL')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs. AL')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='bp', y='rbc', hue='classification', data=df)
plt.title('Scatter Plot of Blood Pressure vs. SG')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Blood Pressure vs. SG')
